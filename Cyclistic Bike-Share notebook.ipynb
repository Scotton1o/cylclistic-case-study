# %% [markdown]
# This is my capstone project to finish the Google Coursera Data Analysis certificate.
# Project by Scott Hebson. December 2025
#
# The scenario is based on a fictional bike-share company based in the Chicago area.
#
# # Ask
# ## What is Cyclistic?
# Cyclistic is a fictional bicycle ride share company in Chicago chosen for this case study. In 2016, Cyclistic launched a successful bike share offering. Since then, the program has grown to a fleet of 5824 bicycles that our geo-tracked and locked into a network of 692 stations across Chicago. The bikes can be unlocked from one station and return to any other station in the system anytime.
# Three options for passes customers may purchase are:
#
# 1.	Single-ride passes
# 2.	Full-day passes
# 3.	Annual memberships

# %% [markdown]
# Customers who purchase single-ride or full-day passes are referred to as “casual riders.” Customers who purchase annual memberships are referred to as “Cyclistic members.”
#
# Cyclistic’s finance analysts have concluded that annual members are much more profitable than casual riders. Although the pricing flexibility helps Cyclistic attract more customers, Director of Marketing: Lily Moreno, believes that maximizing the number of annual members will be key to future growth. Rather than creating a marketing campaign that targets all new customers, Moreno believes there is a solid opportunity to convert casual riders into members. She notes that casual riders are already aware of the Cyclistic program and have chosen Cyclistic for their mobility needs.
#
# Moreno has set a clear goal: design marketing strategies aimed at converting casual riders into annual members. In-order to do that, however, the team needs to better understand how annual members and casual riders differ, why casual riders would buy a membership, and how digital media would affect their marketing tactics. Moreno and her team are interested in analyzing the cyclic historical bike trip data to identify trends.
#
# Three questions will guide the future marketing program:
#
# 1.	How do annual members and casual riders use Cyclistic bikes differently?
# 2.	Why would casual riders buy Cyclistic annual memberships?
# 3.	How can Cyclistic use digital media to influence casual riders to become members?

# %% [markdown]
# I have been assigned question number 1.
#
# I will need to deliver a clear statement of the business task. How do annual members and casual riders use Cyclistic differently?
#
# Guiding questions –
#
# ## What is the problem I am trying to solve?
# I am trying to solve the problem of targeting casual riders of Cyclistic and effectively marketing to them in-order to convert as many casual riders of Cyclistic to annual members. This is crucial to the growth strategy of my stakeholders (the Cyclistic executive team and marketing director: Lily Moreno) I will do this by analyzing the data that shows the differences between casual riders and annual members.
# ## How can your insights drive business decisions?
# My insights can drive business decisions by providing supporting data on the differences between casual riders and annual members. This will highlight any advantages casual riders will have by converting to annual members. I will analyze different behaviors of riders who would be most likely to purchase a membership. This will give my stakeholders valuable information in-order to effectively market to the casual riders.

# %% [markdown]
# ## Identify the business task:
# Provide data and visuals to stakeholders that answer this question: How do annual members and casual riders use Cyclistic differently?
# ## Consider key stakeholders:
# Cyclistic executive team, Director of marketing: Lily Moreno
# ## Deliverable:
# A clear statement of the business task –
# My business task is to analyze data on the Cyclistic ride share customers. I am tasked with analyzing the difference between casual riders and annual members. I will share my findings with supporting data and visuals to my analysis team and stakeholders. The goal of the data analysis team is to provide insights to effectively market to casual riders in-order to convert them to annual members.

# %% [markdown]
# ## Established Metrics
#
# 1.	Total number of rides taken by members versus casual riders.
# 2.	Total number of rides taken by members versus casual riders grouped by rideable_type.
# 3.	Provide data on ride_length. Average/max ride length for members versus casual riders.
# 4.	Total number of rides taken broken down by months and days of the week grouped by member_casual. Look for seasonal trends. (including visuals)
# 5.	Provide data on top ten start_station_name for casual riders. (with visuals)
# 6.	Compare visuals for all station locations versus top ten start_station and make observations.
# 7.	Compare top ten start stations for members versus casual riders for the entire 12 months.

# %% [markdown]
# # Prepare
#
# Tools that I will use for this project are Microsoft Excel, BigQuery SQL server, Tableau, and R.
# I will use Excel to organize and analyze data, SQL to query the data, and Tableau and R for creating data visuals.
#
# Link to the original data used for this project - [Divvy Trip Data Repository](https://divvy-tripdata.s3.amazonaws.com/index.html)

# %% [markdown]
# ## Where is your data located?
# I have downloaded the most recent 12 months of the ride share data and saved it in a folder on my computer. (.csv and .xls files). The 12 files have been merged into a .csv file called cylcistic_2025.csv which is stored on Google Cloud and uploaded to BigQuery SQL server.
#
# I am analyzing all data from November 2024 – October 2025
#
# ## How is the data organized?
# Source Data: The initial data was stored across 12 separate monthly spreadsheets.
#
# Consistency: All 12 spreadsheets maintained matching column structures.
#
# Column Details: The data fields include identifiers, location information, and time and date information.
#
# Current State: The monthly spreadsheets have been merged into a single, comprehensive dataset, to be analyzed using SQL.Are there issues with bias or credibility of this data? Does your data
#
# ## ROCCC?
# (R – reliable, O - original (compare your data against original data source, C – comprehensive, C – current, C - cited (cite your sources)
# Because Cyclistic is a fictional company this data is appropriate for the example and will enable me to answer the business questions. The data has been made available by Motivate International inc. under this [license](https://divvybikes.com/data-license-agreement).
#
# The data is current and comprehensive because it is a sample of the most recent 12 months of bicycle ride share data. Months sampled for this case study were November 2024 – October 2025.
# I was directed to this data by an online Google Coursera data analysis course.
#
# (Note on limitations of the data: This is public data that you can use to explore how different customer types are using Cyclistic bikes. But note that the data-privacy issues prohibit you from using riders’ personally identifiable information. This means that you won’t be able to connect pass purchases to credit card numbers to determine if casual riders live in the Cyclistic service area or if they have purchased multiple single passes)

# %% [markdown]
# I placed 12 months Cyclistic data in folder CSV_folder and used mac terminal to merge datasets using these codes:
#
# Navigate to folder:
# ```bash
# cd ~/Documents/CSV_Folder

# %% [markdown]
# Merge files
# ```bash
# cat *.csv > combined.csv

# %% [markdown]
# renamed combined file: cyclistic_2025
#
# Total rows in the dataset - **5569279**
#
# I could not get Microsoft SQL server to run on my macOS so I loaded the combined data into Google Cloud to be analyzed in BigQuery (upload failed, too many errors. I went to advanced options and changed errors allowed to 1000. Job loaded.
# All tables exported from SQL will be saved in a folder called “SQL tables” to be used for further analysis in Excel, Tableau and Rstudio.

# %% [markdown]
# # Process
#
# Addressing missing values in the data:
#
# Cell 12
# SQL code to count Null values for each Column.
#
# ```sql
# SELECT
#     COUNT(*) - COUNT(ride_id) AS ride_id_nulls,
#     COUNT(*) - COUNT(rideable_type) AS rideable_type_nulls,
#     COUNT(*) - COUNT(started_at) AS started_at_nulls,
#     COUNT(*) - COUNT(ended_at) AS ended_at_nulls,
#     COUNT(*) - COUNT(start_station_name) AS start_station_name_nulls,
#     COUNT(*) - COUNT(start_station_id) AS start_station_id_nulls,
#     COUNT(*) - COUNT(end_station_name) AS end_station_name_nulls,
#     COUNT(*) - COUNT(end_station_id) AS end_station_id_nulls,
#     COUNT(*) - COUNT(start_lat) AS start_lat_nulls,
#     COUNT(*) - COUNT(start_lng) AS start_lng_nulls,
#     COUNT(*) - COUNT(end_lat) AS end_lat_nulls,
#     COUNT(*) - COUNT(end_lng) AS end_lng_nulls,
#     COUNT(*) - COUNT(member_casual) AS member_casual_nulls
# FROM `temptables-465123.case_study.cyclistic_2025`

# %% [markdown]
# ## Null values
# Addressing missing values in the data:

# %%
my_data <- read.csv("null_values_long.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

my_data
# Out:
#    Column                   Null.Values
# 1  ride_id_nulls                  0
# 2  rideable_type_nulls            0
# 3  started_at_nulls               0
# 4  ended_at_nulls                 0
# 5  start_station_name_nulls 1166861
# 6  start_station_id_nulls   1166861
# 7  end_station_name_nulls   1219784
# 8  end_station_id_nulls     1219784
# 9  start_lat_nulls                0
# 10 start_lng_nulls                0
# 11 end_lat_nulls               5460
# 12 end_lng_nulls               5460
# 13 member_casual_nulls            0

# %% [markdown]
# There are no missing values for columns ride_id and member_casual. So we will not remove rows with Null values.

# %%
SQL code to count all values for each column:
```sql
SELECT
    COUNT(ride_id) AS ride_id_total,
    COUNT(rideable_type) AS rideable_type_total,
    COUNT(started_at) AS started_at_total,
    COUNT(ended_at) AS ended_at_total,
    COUNT(start_station_name) AS start_station_name_total,
    COUNT(start_station_id) AS start_station_id_total,
    COUNT(end_station_name) AS end_station_name_total,
    COUNT(end_station_id) AS end_station_id_total,
    COUNT(start_lat) AS start_lat_total,
    COUNT(start_lng) AS start_lng_total,
    COUNT(end_lat) AS end_lat_total,
    COUNT(end_lng) AS end_lng_total,
    COUNT(member_casual) AS member_casual_total
FROM `temptables-465123.case_study.cyclistic_2025`

# %%
#R Code
total_data <- read.csv("total_value_count.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

total_data
# Out:
#    total.values.per.column         X
# 1  Sum of member_casual_total      5569279
# 2  Sum of end_lng_total            5563819
# 3  Sum of end_lat_total            5563819
# 4  Sum of start_lng_total          5569279
# 5  Sum of start_lat_total          5569279
# 6  Sum of end_station_id_total     4349495
# 7  Sum of end_station_name_total   4349495
# 8  Sum of start_station_id_total   4402418
# 9  Sum of start_station_name_total 4402418
# 10 Sum of ended_at_total           5569279
# 11 Sum of started_at_total         5569279
# 12 Sum of rideable_type_total      5569279
# 13 Sum of ride_id_total            5569279

# %% [markdown]
# SQL code to count Null values based on rideable_type.
# ```sql
# SELECT
#     rideable_type,
#     COUNT(*) AS total_rides,
#     COUNT(*) - COUNT(ride_id) AS ride_id_nulls,
#     COUNT(*) - COUNT(started_at) AS started_at_nulls,
#     COUNT(*) - COUNT(ended_at) AS ended_at_nulls,
#     COUNT(*) - COUNT(start_station_name) AS start_station_name_nulls,
#     COUNT(*) - COUNT(start_station_id) AS start_station_id_nulls,
#     COUNT(*) - COUNT(end_station_name) AS end_station_name_nulls,
#     COUNT(*) - COUNT(end_station_id) AS end_station_id_nulls,
#     COUNT(*) - COUNT(start_lat) AS start_lat_nulls,
#     COUNT(*) - COUNT(start_lng) AS start_lng_nulls,
#     COUNT(*) - COUNT(end_lat) AS end_lat_nulls,
#     COUNT(*) - COUNT(end_lng) AS end_lng_nulls,
#     COUNT(*) - COUNT(member_casual) AS member_casual_nulls
# FROM `temptables-465123.case_study.cyclistic_2025`
# WHERE rideable_type IN ('electric_bike', 'classic_bike')
# GROUP BY rideable_type;

# %%
#R Code
rideable_nulls <- read.csv("nulls_rideable_type_long.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

rideable_nulls
# Out:
#    column                   electric_bike classic_bike
# 1  ride_id_nulls                  0          0
# 2  started_at_nulls               0          0
# 3  ended_at_nulls                 0          0
# 4  start_station_name_nulls 1166861          0
# 5  start_station_id_nulls   1166861          0
# 6  end_station_name_nulls   1214217       5567
# 7  end_station_id_nulls     1214217       5567
# 8  start_lat_nulls                0          0
# 9  start_lng_nulls                0          0
# 10 end_lat_nulls                  0       5460
# 11 end_lat_nulls                  0       5460
# 12 member_casual_nulls            0          0

# %% [markdown]
# Take away: These results indicate that there are significantly more missing values for electric bikes than there are for classic bikes.

# %%
# 1. Load required libraries
library(ggplot2)
library(tidyr)
library(dplyr)

# 2. Import the data
df <- read.csv("nulls_rideable_type.csv")

# 3. Reshape the data for specific null columns
df_long <- df %>%
  pivot_longer(
    cols = c("ride_id_nulls", "started_at_nulls", "ended_at_nulls", 
             "start_station_name_nulls", "start_station_id_nulls", 
             "end_station_name_nulls", "end_station_id_nulls", 
             "start_lat_nulls", "start_lng_nulls", 
             "end_lat_nulls", "end_lng_nulls", "member_casual_nulls"), 
    names_to = "column_name", 
    values_to = "null_count"
  )

# 4. Create the bar chart separated by rideable_type
ggplot(df_long, aes(x = column_name, y = null_count, fill = rideable_type)) +
  # Use geom_col to plot actual numeric values from the CSV
  geom_col() +
  
  # Separate by rideable_type into columns (classic_bike vs electric_bike)
  facet_grid(. ~ rideable_type) +
  
  # Standard 2025 reporting labels and formatting
  labs(title = "Missing Data (Nulls) by Bike Type",
       subtitle = "Comparative analysis of classic vs electric bikes",
       x = "Data Column",
       y = "Total Null Count") +
  
  # Professional styling
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1), # Rotates labels for readability
        legend.position = "bottom")
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on 'nulls_rideable_type.csv'”
# plot without title

# %% [markdown]
# Dealing with inconsistencies with start_station_name and start_station_id:
# Ran SQL query to view start_station_name with matching start_station_id and rideable_type. I was checking to see if the different station_id is related to rideable_type. This theory proved incorrect. Station ID is not based on the use of a different bike type.
# The analysis of start_station_name, start_station_id, start_lat and start_lng reveals that there are a range of ID and latitude and longitude values. This is because it represents a neighborhood and not a station.
#
# Example:

# %%
#R Code
rideable_nulls <- read.csv("station_location_example.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

rideable_nulls
# Out:
#   start_station_name        start_station_id start_station_id.1 start_lng
# 1 Aberdeen St & 103rd St    CHI01976         41.70704           -87.65022
# 2 Aberdeen St & 103rd St    CHI01976         41.70709           -87.65022
# 3 Aberdeen St & 103rd St    24425            41.70704           -87.65022
# 4 Aberdeen St & Carroll Ave CHI02056         41.88820           -87.65463
# 5 Aberdeen St & Carroll Ave CHI02056         41.88815           -87.65459
# 6 Aberdeen St & Carroll Ave CHI02056         41.88818           -87.65462
# 7 Aberdeen St & Carroll Ave CHI02056         41.88822           -87.65460

# %% [markdown]
# I made a geographic visual of all start station locations in Tableau.
# <div class='tableauPlaceholder' id='viz1767146474310' style='position: relative'><noscript><a href='#'><img alt='All Cyclistic start station locations ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;St&#47;StartStationlocations&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='StartStationlocations&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;St&#47;StartStationlocations&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1767146474310');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# # Analyze
#
# ## Total Count of casual riders vs. members.
#
#
# SQL code to determine total values grouped by member_casual (total rides taken)
# ```sql
# SELECT
#     member_casual,
#     COUNT(*) AS total_records,
#     COUNT(ride_id) AS ride_id_count,
#     COUNT(rideable_type) AS rideable_type_count,
#     COUNT(started_at) AS started_at_count,
#     COUNT(ended_at) AS ended_at_count,
#     COUNT(start_station_name) AS start_station_name_count,
#     COUNT(start_station_id) AS start_station_id_count,
#     COUNT(end_station_name) AS end_station_name_count,
#     COUNT(end_station_id) AS end_station_id_count,
#     COUNT(start_lat) AS start_lat_count,
#     COUNT(start_lng) AS start_lng_count,
#     COUNT(end_lat) AS end_lat_count,
#     COUNT(end_lng) AS end_lng_count
# FROM `temptables-465123.case_study.cyclistic_2025`
# GROUP BY member_casual;

# %%
#R Code
library(ggplot2)
library(readr)
library(scales) # Needed for comma formatting

# The file path has been changed from a Kaggle input path 
# to a local or relative path (e.g., in the same directory as the notebook)
ggplot(read_csv("total_member_casual.csv",
                show_col_types = FALSE),
       aes(x = member_casual, y = total_records, fill = member_casual)) +
  geom_col() +
  geom_text(aes(label = scales::comma(total_records)),
            position = position_stack(vjust = 0.5),
            color = "white",
            fontface = "bold",
            size = 5) +
  labs(title = "Total Records by Rider Type",
       subtitle = "Analysis of annual members vs. casual riders (2025)",
       x = "Rider Category",
       y = "Total Number of Records",
       caption = "Data source: total_member_casual.csv") +
  theme_minimal() +
  theme(legend.position = "none",
        plot.title = element_text(face = "bold", size = 14))
# Out:
# plot without title

# %% [markdown]
# ## Preference for classic bikes vs. electric bikes.
#
# SQL code to count rides taken grouped by member_id and ordered by rideable_type.
# ```sql
# SELECT
#     member_casual,
#     rideable_type,
#     COUNT(ride_id) AS total_rides
# FROM
#     `temptables-465123.case_study.cyclistic_2025`
# GROUP BY
#     member_casual,
#     rideable_type
# ORDER BY
#     rideable_type;

# %%
# R Code
library(ggplot2)
library(tidyr)
library(dplyr)
library(readr)
suppressPackageStartupMessages(library(scales))

# The file path has been changed from a Kaggle input path 
# to a local or relative path (e.g., in the same directory as the notebook)
df_long <- read_csv("./rideable_type2.csv",
                    show_col_types = FALSE) %>%
  pivot_longer(
    cols = c("casual_classic_bike", "casual_electric_bike",
             "member_classic_bike", "member_electric_bike"),
    names_to = "category",
    values_to = "value"
  )

ggplot(df_long, aes(x = category, y = value, fill = category)) +
  geom_col() +
  geom_text(aes(label = comma(value)),
            position = position_stack(vjust = 0.5),
            color = "white",
            fontface = "bold") +
  scale_fill_manual(values = c(
    "casual_classic_bike" = "hotpink",
    "casual_electric_bike" = "hotpink",
    "member_classic_bike" = "purple4",
    "member_electric_bike" = "purple4"
  ))
# Out:
# plot without title

# %% [markdown]
# Take away: Both members and casual riders use electric bikes more than classic bikes.
#
# ## Average ride length.
#
# In SQL calculate ride_length then calculate average ride_length grouped by member_casual and grouped by month
# ```sql
# -- Step A: Add the new column
# ALTER TABLE `temptables-465123.case_study.cyclistic_2025`
# ADD COLUMN ride_length INT64;
#
# -- Step B: Populate with the difference in seconds
# UPDATE `temptables-465123.case_study.cyclistic_2025`
# SET ride_length = TIMESTAMP_DIFF(ended_at, started_at, SECOND)
# WHERE started_at IS NOT NULL AND ended_at IS NOT NULL;
#
# SELECT
#     member_casual,
#     EXTRACT(MONTH FROM started_at) AS ride_month,
#     AVG(ride_length) AS avg_ride_length_seconds
# FROM `temptables-465123.case_study.cyclistic_2025`
# WHERE ride_length IS NOT NULL
# GROUP BY
#     member_casual,
#     ride_month
# ORDER BY
#     ride_month,
#     member_casual;

# %% [markdown]
# SQL code to list average ride_length formatted by hh:mm:ss grouped by member_casual as rows and month as columns
# ```sql
# SELECT
#     member_casual,
#     -- January
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 1 THEN ride_length END) AS INT64))) AS Jan_Avg,
#     -- February
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 2 THEN ride_length END) AS INT64))) AS Feb_Avg,
#     -- March
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 3 THEN ride_length END) AS INT64))) AS Mar_Avg,
#     -- April
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 4 THEN ride_length END) AS INT64))) AS Apr_Avg,
#     -- May
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 5 THEN ride_length END) AS INT64))) AS May_Avg,
#     -- June
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 6 THEN ride_length END) AS INT64))) AS Jun_Avg,
#     -- July
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 7 THEN ride_length END) AS INT64))) AS Jul_Avg,
#     -- August
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 8 THEN ride_length END) AS INT64))) AS Aug_Avg,
#     -- September
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 9 THEN ride_length END) AS INT64))) AS Sep_Avg,
#     -- October
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 10 THEN ride_length END) AS INT64))) AS Oct_Avg,
#     -- November
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 11 THEN ride_length END) AS INT64))) AS Nov_Avg,
#     -- December
#     TIME(TIMESTAMP_SECONDS(CAST(AVG(CASE WHEN EXTRACT(MONTH FROM started_at) = 12 THEN ride_length END) AS INT64))) AS Dec_Avg
# FROM `temptables-465123.case_study.cyclistic_2025`
# WHERE ride_length IS NOT NULL
# GROUP BY member_casual;

# %%
#R Code
total_data <- read.csv("avg_ride_length_long.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

total_data
# Out:
#    month member  casual
# 1  Jan   0:10:04 0:14:36
# 2  Feb   0:10:03 0:14:38
# 3  Mar   0:11:13 0:20:46
# 4  Apr   0:11:19 0:21:40
# 5  May   0:12:08 0:24:11
# 6  Jun   0:12:56 0:25:23
# 7  Jul   0:13:21 0:24:23
# 8  Aug   0:13:05 0:23:36
# 9  Sep   0:12:41 0:21:35
# 10 Oct   0:12:21 0:20:24
# 11 Nov   0:11:05 0:19:24
# 12 Dec   0:10:45 0:17:36

# %% [markdown]
# Take away: casual riders have longer average ride_length each month. Average ride_length for both members and casual riders increase during the months of March and begin to decline in July.
#
# ## Max ride length.
#
# SQL code to calculate max ride_length grouped by member_casual and ordered by month
# ```sql
# SELECT
#     member_casual,
#     -- Extracts the month number for grouping and ordering
#     EXTRACT(MONTH FROM started_at) AS ride_month,
#     -- Converts the max ride_length (in seconds) to HH:MM:SS format
#     TIME(TIMESTAMP_SECONDS(MAX(ride_length))) AS max_ride_length_formatted
# FROM
#     `temptables-465123.case_study.cyclistic_2025`
# GROUP BY
#     member_casual,
#     ride_month
# ORDER BY
#     ride_month;

# %%
#R Code
total_data <- read.csv("max_ride_long.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

total_data
# Out:
#    month casual_max_ride member_max_ride
# 1  Jan   0:59:56         0:59:57
# 2  Feb   0:59:56         0:59:56
# 3  Mar   1:59:55         0:59:57
# 4  Apr   0:59:57         0:59:57
# 5  May   0:59:58         0:59:57
# 6  Jun   2:14:54         0:59:58
# 7  Jul   1:00:53         0:59:57
# 8  Aug   0:59:58         0:59:58
# 9  Sep   0:59:58         0:59:58
# 10 Oct   0:59:57         0:59:57
# 11 Nov   1:00:51         0:59:56
# 12 Dec   0:59:57         0:59:55

# %% [markdown]
# Take Away: casual riders had significantly longer max ride_length during March and June.
#
# ## Rides by Month and Day.
#
# Total number of rides taken broken down by months and days of the week grouped by member_casual. Looking for seasonal trends.
# In SQL I added a column named “day_of_week” listing the correct day based on values in the “started_at” column. To calculate start day.
# I also added column named “month” that calculates the correct month based on values in the “started_at” column. To list the start month.
# Then I ran SQL code to give the total count of values in “ride_id” grouped by member_casual, day_of_week, and month.
# ```sql
# SELECT
#     member_casual,
#     month,
#     day_of_week,
#     COUNT(ride_id) AS ride_count
# FROM `temptables-465123.case_study.cyclistic_2025`
# GROUP BY
#     member_casual,
#     month,
#     day_of_week
# ORDER BY
#     member_casual;

# %%
#R Code
library(ggplot2)
library(dplyr)
library(readr)

# File path updated for a generic Jupyter environment
df_rides <- read_csv("ride_count.csv",
                     show_col_types = FALSE)

df_summer <- df_rides %>%
  filter(month %in% c("June", "July", "August")) %>%
  mutate(
    # Ensure months follow calendar order
    month = factor(month, levels = c("June", "July", "August")),
    # Ensure days of week follow calendar order
    day_of_week = factor(day_of_week, levels = c("Monday", "Tuesday", "Wednesday",
                                                  "Thursday", "Friday", "Saturday", "Sunday"))
  )

ggplot(df_summer, aes(x = day_of_week, y = ride_count, fill = member_casual)) +
  geom_col(position = "dodge") +
  facet_wrap(~ month) +
  labs(title = "Summer Ride Counts: June - August 2025",
       subtitle = "Comparative analysis of member vs. casual usage by day of week") +
  # --- Add this line to tilt x-axis labels by 45 degrees ---
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# **IMPORTANT Take away:** the only time that casual riders have a higher ride count than members is on Saturday and Sunday during the months of June, July, August. The best time to market to casual riders is the weekends during the summer months.

# %% [markdown]
# ## Top ten start stations
#
# Provide data on top ten start_station_name for casual riders.
# This sql code gives Top 10 start_station_name for casual riders on day_of_week Saturday and Sunday during months of June, July, Aug. Without including Null values
# ```sql
# SELECT
#     start_station_name,
#     COUNT(ride_id) AS ride_count
# FROM temptables-465123.case_study.cyclistic_2025
# WHERE
#     -- Filter for casual riders
#     member_casual = 'casual'
#     -- Filter for specific months (6=June, 7=July, 8=August)
#     AND EXTRACT(MONTH FROM started_at) IN (6, 7, 8)
#     -- Filter for weekend days
#     AND day_of_week IN ('Saturday', 'Sunday')
#     -- Exclude null values from the grouping column and ID column
#     AND start_station_name IS NOT NULL
#     AND ride_id IS NOT NULL
# GROUP BY
#     start_station_name
# ORDER BY
#     ride_count DESC
# LIMIT 10;

# %%
#R Code
total_data <- read.csv("top_ten_start.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

total_data
# Out:
#    start_station_name                 ride_count
# 1  DuSable Lake Shore Dr & Monroe St  7273
# 2  Navy Pier                          6658
# 3  Streeter Dr & Grand Ave            6229
# 4  Michigan Ave & Oak St              5965
# 5  DuSable Lake Shore Dr & North Blvd 5608
# 6  Theater on the Lake                4630
# 7  Millennium Park                    4146
# 8  Shedd Aquarium                     3645
# 9  Dusable Harbor                     3593
# 10 Montrose Harbor                    3070

# %% [markdown]
# SQL code to show top ten start_station_name, start_station_id, start_lat and start_lng used by casual-riders on Saturday and Sunday during months June, July, and August. This will be used to build a geographic visual in Tableau.
# ```sql
# SELECT
#     start_station_name,
#     start_station_id,
#     start_lat,
#     start_lng,
#     COUNT(ride_id) AS total_rides
# FROM `temptables-465123.case_study.cyclistic_2025`
# WHERE
#     -- Filter for casual riders only
#     member_casual = 'casual'
#     -- Filter for June (6), July (7), and August (8)
#     AND EXTRACT(MONTH FROM started_at) IN (6, 7, 8)
#     -- Filter for weekends (1 = Sunday, 7 = Saturday in BigQuery)
#     AND EXTRACT(DAYOFWEEK FROM started_at) IN (1, 7)
#     -- Exclude null station data to ensure clean results
#     AND start_station_name IS NOT NULL
# GROUP BY
#     start_station_name,
#     start_station_id,
#     start_lat,
#     start_lng
# ORDER BY
#     total_rides DESC

# %% [markdown]
# I made a geographic visual in Tableau of all start station locations used by casual riders on Saturday and Sunday during Jun - Aug.
#
# <div class='tableauPlaceholder' id='viz1767120566535' style='position: relative'><noscript><a href='#'><img alt='Top ten start locations for casual riders on the weekend during the summer months ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;To&#47;Top_ten_start_station&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Top_ten_start_station&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;To&#47;Top_ten_start_station&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1767120566535');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %%
**Note:** location for Navy Pier and Streeter Dr & Grand Ave sit right on top of one another on the map.

Take away: most popular stations for casual riders at these times are along the lakeshore of Chicago.

# %% [markdown]
# Compare top ten start stations for members versus casual riders for the entire 12 months.
# SQL code to show start_station_name, start_lat and start_lng sorted by count of ride_id in descending order where member_casual = casual.
#
# ```sql
# SELECT
#     start_station_name,
#     start_lat,
#     start_lng,
#     COUNT(ride_id) AS total_rides
# FROM
#     `temptables-465123.case_study.cyclistic_2025`
# WHERE
#     member_casual = 'casual'
#     AND start_station_name IS NOT NULL
# GROUP BY
#     start_station_name,
#     start_lat,
#     start_lng
# ORDER BY
#     total_rides DESC
# LIMIT 10;

# %% [markdown]
# **Top ten start stations used by casual riders over entire 12 months**
# Table includes latitude and longitude data to visualize on a map in Tableau.

# %%
#R Code
total_data <- read.csv("geo_top_start_casual.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

total_data
# Out:
#    start_station_name                 start_lat start_lng total_rides
# 1  DuSable Lake Shore Dr & Monroe St  41.88096  -87.61674 30720
# 2  Streeter Dr & Grand Ave            41.89228  -87.61204 25463
# 3  Navy Pier                          41.89228  -87.61204 25392
# 4  Michigan Ave & Oak St              41.90096  -87.62378 22153
# 5  DuSable Lake Shore Dr & North Blvd 41.91172  -87.62680 19313
# 6  Millennium Park                    41.88103  -87.62408 19049
# 7  Shedd Aquarium                     41.86723  -87.61536 16847
# 8  Theater on the Lake                41.92628  -87.63083 15650
# 9  Dusable Harbor                     41.88698  -87.61281 15547
# 10 Michigan Ave & 8th St              41.87277  -87.62398 11073

# %% [markdown]
# SQL code to show top ten start_station_name used by members for the entire 12 months.
# ```sql
# SELECT
#     start_station_name,
#     start_lat,
#     start_lng,
#     COUNT(ride_id) AS total_rides
# FROM
#     `temptables-465123.case_study.cyclistic_2025`
# WHERE
#     member_casual = 'member'
#     AND start_station_name IS NOT NULL
# GROUP BY
#     start_station_name,
#     start_lat,
#     start_lng
# ORDER BY
#     total_rides DESC
# LIMIT 10;

# %%
**Top ten start stations used by members over entire 12 months**
Table includes latitude and longitude data to visualize on a map in Tableau.

# %%
#R Code
total_data <- read.csv("geo_top_start_member.csv")

options(repr.matrix.max.rows = Inf, repr.matrix.max.cols = Inf)

total_data
# Out:
#    start_station_name           start_lat start_lng total_rides
# 1  Kingsbury St & Kinzie St     41.88918  -87.63851 30121
# 2  Clinton St & Washington Blvd 41.88338  -87.64117 24316
# 3  Clinton St & Madison St      41.88275  -87.64119 22155
# 4  Canal St & Madison St        41.88241  -87.63977 21563
# 5  Clinton St & Jackson Blvd    41.87832  -87.64098 18474
# 6  Wells St & Elm St            41.90322  -87.63432 18199
# 7  State St & Chicago Ave       41.89662  -87.62858 18033
# 8  Wells St & Concord Ln        41.91213  -87.63466 17792
# 9  University Ave & 57th St     41.79148  -87.59986 16736
# 10 Canal St & Adams St          41.87926  -87.63990 16655

# %% [markdown]
# ## Dashboard visual in Tableau.
#
# This is a comparison of top ten start station locations used by casual riders AND annual members:
#
# <div class='tableauPlaceholder' id='viz1767121219239' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;To&#47;ToptenstartstationsforCyclisticcasual-ridersandmembersdashboard&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='ToptenstartstationsforCyclisticcasual-ridersandmembersdashboard&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;To&#47;ToptenstartstationsforCyclisticcasual-ridersandmembersdashboard&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1767121219239');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='777px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# Take away: locations of the most popular start stations for casual riders differ from those of the annual members. Popular start stations for casual riders are along the eastern lakeshore while popular start stations for members are in the city and further south near Hyde park.

# %%
# Share
## What story does this data tell us?


## Rider Base and Conversion Potential
Annual members currently outnumber casual riders by 28%. This variance highlights a significant opportunity to develop targeted campaigns aimed at converting the casual rider segment into annual members.

## Rideable Type Preferences
Both rider demographics demonstrate a preference for electric bikes. Marketing strategies should prioritize ensuring high availability and prominent promotion of the electric fleet.

## Usage Patterns and Timing

Casual riders generally take longer average trips and exhibit significantly higher maximum ride lengths specifically during March and June.
The sole periods where casual riders surpass members in ride count are on Saturdays and Sundays in the summer months (June, July, August). The optimal time to market to this demographic is explicitly during summer weekends.
## Location-Based Targeting

Popular start station locations differ markedly between groups.
Casual riders favor stations along the eastern lakeshore.
Annual members prefer stations within the inner city and southern areas near Hyde Park.
The most effective location-based marketing campaigns should be deployed along the eastern lakeshore to capture casual rider attention.
